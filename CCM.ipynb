# %% [markdown]
# <a href="https://colab.research.google.com/github/symphonymarie/CCM/blob/main/CCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title CHARACTER CREATION MODULE
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# bring in all the things
import time
import random
from IPython.display import Audio, display
import random

class HiddenAudio(Audio):
    def _repr_html_(self):
        audio = super()._repr_html_()
        audio = audio.replace('<audio', f'<audio onended="this.parentNode.removeChild(this)"')
        return f'<div style="display:none">{audio}</div>'

#os.system('color 0b')

print("""\
  â•¦â”Œâ”â”Œâ”¬â”â”Œâ”€â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”Œâ”€â”â”¬  â”¬  â”Œâ”€â”â”¬â”€â”
  â•‘â”‚â”‚â”‚â”‚ â”œâ”¤ â”œâ”¬â”˜â””â”€â” â”‚ â”œâ”¤ â”‚  â”‚  â”œâ”€â”¤â”œâ”¬â”˜
  â•©â”˜â””â”˜â”´ â””â”€â”˜â”´â””â”€â””â”€â”˜ â”´ â””â”€â”˜â”´â”€â”˜â”´â”€â”˜â”´ â”´â”´â””â”€
  â•”â•â•—â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”  â•”â•â•—â”Œâ”€â”â”Œâ”â”Œâ”Œâ”€â”â”Œâ”¬â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”¬â”Œâ”€â”â”Œâ”â”Œ
  â•šâ•â•—â”œâ”€â”˜â”œâ”€â”¤â”‚  â”œâ”¤   â• â•â•â”œâ”¤ â”‚â”‚â”‚â”œâ”¤  â”‚ â”œâ”¬â”˜â”œâ”€â”¤ â”‚ â”‚â”‚ â”‚â”‚â”‚â”‚
  â•šâ•â•â”´  â”´ â”´â””â”€â”˜â””â”€â”˜  â•©  â””â”€â”˜â”˜â””â”˜â””â”€â”˜ â”´ â”´â””â”€â”´ â”´ â”´ â”´â””â”€â”˜â”˜â””â”˜
  â•”â•¦â•—â”¬ â”¬â”¬â”Œâ”â”Œâ”¬â”Œâ”€â”¬â”Œâ”â”Œâ”Œâ”€â”  â•”â•¦â•—â”Œâ”€â”â”Œâ”€â”â”¬ â”¬â”¬â”Œâ”â”Œâ”Œâ”€â”
   â•‘ â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”´â”â”‚â”‚â”‚â”‚â”‚ â”¬  â•‘â•‘â•‘â”œâ”€â”¤â”‚  â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”¤
   â•© â”´ â”´â”´â”˜â””â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜  â•© â•©â”´ â”´â””â”€â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜
 """)

print("--WELCOME NEW ASTRONEER!---")
input("Press enter to begin.")
print()

# set up variables

opta = 0
optb = 0
optc = 0
optd = 0
optf = 0
progress = 0

time.sleep(1)
print("Loading...")
time.sleep(.5)
print()
print("AI Evaluator Connection Established")
time.sleep(.51)
display(HiddenAudio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/audio.wav', autoplay=True))
print()

nums = ["Â·",":","*","o"]
tm = 0
print("""\


                                   @@(@#@@                @@@                     /@
    @@                           @   @@@   @,            @ @ @                    @@
   @@                           @   @@ #@   @        @ .@ .@  @ *@         #      @@     @
  @@                            @  /@   @%  @         .@@@#@ @@@              @ @@@@@* @
  @@.                            @   @@@   @             .@@@               @@@@@@@@@@@ @@
  @@@      @ .,           @        @@ @,@@              @@   @*            .@@@@@@@@@@@@@&
   @@@@  @   @           @           *@#              .@      ,@              .@@@@@@@@
    .@@@@   @         @@@             @,              @         @                 @@   @
       &@@@@@@@@@@@@@@.             @@@@@               @(   @@            @      @@
             %@@@(                    @                  .@@@                     @@
                                                           @                       @

                    """)
time.sleep(1)
print("""\

   __             __        __  ___  ___  __
  /  ` |__|  /\  |__)  /\  /  `  |  |__  |__)
  \__, |  | /~~\ |  \ /~~\ \__,  |  |___ |  \
   __        __   __   ___  __  ___    __
  /__` |  | / _` / _` |__  /__`  |  | /  \ |\ |
  .__/ \__/ \__> \__> |___ .__/  |  | \__/ | \|
       __   __             ___
  |\/| /  \ |  \ |  | |    |__
  |  | \__/ |__/ \__/ |___ |___

                    """)
time.sleep(1)
while tm < 9:
    print(random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),random.randrange(1,5)* " ",
    random.choice(nums),)

    tm = tm + 0.1

    time.sleep(0.1)
print()
print("- INSTRUCTIONS -")
time.sleep(.5)
print("Respond to prompts with 1, 2, 3, or 4 and then press ENTER.")
time.sleep(1.5)
print()
print("Loading...")
time.sleep(1)
print("- MODULE REGISTERED -")
time.sleep(2.5)
print( "STARTING CHARACTER ANALYSIS")
time.sleep(1)
time.sleep(.5)
print()
print("Reading data...")
time.sleep(1)


# define the ask function globals
def ask (q, QAudio, qs, qt, a, b, c, d):
  global opta
  global optb
  global optc
  global optd
  global optf
  global progress
  import time
  print()
  print()

  # the question format
  display(HiddenAudio(filename=QAudio, autoplay=True ))
  print(q)
  time.sleep(.5)
  print(qt)
  time.sleep(float(qs))
  print("1 - " + a)
  time.sleep(1)
  print("2 - " + b)
  time.sleep(1)
  print("3 - " + c)
  time.sleep(1)
  print("4 - " + d)
  print()

  # did they give us a number? this is mostly to block accidental input, or return key mashing...

  while True:
    try:
      ans = int(input("Enter an integer number: "))
      break
    except ValueError:
      # they did not, in fact, give us a number...
        print("Please input integer only...")
        continue

  print("Response recorded:", ans)
  print()

  # Get user's answer and assign variables
  if ans == int("1"):
    opta += 1
    progress += 1
  elif ans == int("2"):
    optb += 1
    progress += 1
  elif ans == int("3"):
    optc += 1
    progress += 1
  elif ans == int("4"):
    optd += 1
    progress += 1
  else:
    # user is a smartass, waste their time
    print("Invalid response recorded!")
    optf += 1
    progress += 1
  print()

# the actual questions
while optf < 1 and progress < 8:
    try:
      ask(q="001", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q1.wav', qt="You need someone to do something for you. Which is your most likely approach?", qs="7", a="Make it seem like it was their idea.", c="Convince them everyone else has already agreed.", d="Blackmail.", b="Butter them up.")
      ask(q="002", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q2.wav', qs="4", qt="A stranger has left their wallet behind at the commissary. What do you do?", a="Check their ID. Maybe take some cash. Return it to their department head.", b="Check their ID. Return it to their department head. Do not take any cash.", c="Drop it off at security. Maybe take some cash.", d="Take some cash. Maybe take the wallet to security.")
      ask(q="003", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q3.wav', qs="3", qt="How do you handle verbal disagreements?", a="I live to debate.", b="I like to take all sides into account before committing.", c="I try to bring people around to my point of view. ", d="I disagree and I leave.")
      ask(q="004", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q4.wav', qs="9", qt=" You and Randy have just gone on break. Randy is washing up at the sink. The coffeepot is almost empty. What do you do?", a="Take the last of it and turn the coffee pot off.", b="Make a new pot.", c="Take the last of it and tell Randy he'll have to make a new pot.", d="Take the last of it.")
      ask(q="005", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q5.wav', qs="13", qt="Choose a word.", a="Analytical", b="Comfort", c="Collaborate ", d="Spontaneous")
      ask(q="006", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q6.wav', qs="2.5", qt="Choose a word.", a="Mesmerize", b="Nurture", c="Motivate", d="Enviable")
      ask(q="007", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q7.wav', qs=".5", qt="Choose a word.", a="Agreeable", b="Soup", c="Staunch", d="Mechanical")
      ask(q="008", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q8.wav', qs="5", qt="Congratulations. You made it to the final question. Pick an element.", a="Gold.", b="Oxygen.", c="Uranium.", d="Helium.")
    except Exception as e:
      print(e)

######## END REPEAT ####
######## OUTPUT ########

# drumroll please...
print("RESULTS")
time.sleep(.5)
#Naughty result, the four regular results, and the tiebreak result
if optf > 0:
  time.sleep(.5)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/idiot.wav', autoplay=True))
  time.sleep(4)
  print("""\

  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@                @@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@                         @@@@@@@@@@@@@@@
  @@@@@@@@@@@@                               @@@@@@@@@@@@
  @@@@@@@@@@                                   @@@@@@@@@@
  @@@@@@@@@         @@@              @@@         @@@@@@@@
  @@@@@@@,       @@@@@@@@         @@@@@@@@        @@@@@@@
  @@@@@@@           @@@              @@@           @@@@@@
  @@@@@@                  @@@@@@@/                 @@@@@@
  @@@@@@                 @@@@@@@@@/                 @@@@@
  @@@@@@         @@%     /@@@@@@@@      @@@        &@@@@@
  @@@@@@.        @@@        (@@        @@@         @@@@@@
  @@@@@@@         /@@@               &@@@         @@@@@@@
  @@@@@@@@          /@@@@#        @@@@@          @@@@@@@@
  @@@@@@@@@@            @@@@@@@@@@@*            @@@@@@@@@
  @@@@@@@@@@@/                                @@@@@@@@@@@
  @@@@@@@@@@@@@@                           %@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@                   ,@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
  ___     _             _        __   ___
  / __| __| |_  ___  ___| |  ___ / _| |   \ _  _ _ _  __ ___ ___
  \__ \/ _| ' \/ _ \/ _ \ | / _ \  _| | |) | || | ' \/ _/ -_|_-<
  |___/\__|_||_\___/\___/_| \___/_|   |___/ \_,_|_||_\__\___/__/

  """)
  print("You are School of Dunces")
  time.sleep(16.5)
  print("Alert! Evaluator has terminated the session!")
  print("-------")
  print("Evaluator feedback: You know what you did.")
  time.sleep(3)
  print("Resetting....")
  input("Press enter to reconnect.")
  #here we go again...
  os.system('color 0b')
  print("""\
  â•¦â”Œâ”â”Œâ”¬â”â”Œâ”€â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”Œâ”€â”â”¬  â”¬  â”Œâ”€â”â”¬â”€â”
  â•‘â”‚â”‚â”‚â”‚ â”œâ”¤ â”œâ”¬â”˜â””â”€â” â”‚ â”œâ”¤ â”‚  â”‚  â”œâ”€â”¤â”œâ”¬â”˜
  â•©â”˜â””â”˜â”´ â””â”€â”˜â”´â””â”€â””â”€â”˜ â”´ â””â”€â”˜â”´â”€â”˜â”´â”€â”˜â”´ â”´â”´â””â”€
  â•”â•â•—â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”  â•”â•â•—â”Œâ”€â”â”Œâ”â”Œâ”Œâ”€â”â”Œâ”¬â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”¬â”Œâ”€â”â”Œâ”â”Œ
  â•šâ•â•—â”œâ”€â”˜â”œâ”€â”¤â”‚  â”œâ”¤   â• â•â•â”œâ”¤ â”‚â”‚â”‚â”œâ”¤  â”‚ â”œâ”¬â”˜â”œâ”€â”¤ â”‚ â”‚â”‚ â”‚â”‚â”‚â”‚
  â•šâ•â•â”´  â”´ â”´â””â”€â”˜â””â”€â”˜  â•©  â””â”€â”˜â”˜â””â”˜â””â”€â”˜ â”´ â”´â””â”€â”´ â”´ â”´ â”´â””â”€â”˜â”˜â””â”˜
  â•”â•¦â•—â”¬ â”¬â”¬â”Œâ”â”Œâ”¬â”Œâ”€â”¬â”Œâ”â”Œâ”Œâ”€â”  â•”â•¦â•—â”Œâ”€â”â”Œâ”€â”â”¬ â”¬â”¬â”Œâ”â”Œâ”Œâ”€â”
   â•‘ â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”´â”â”‚â”‚â”‚â”‚â”‚ â”¬  â•‘â•‘â•‘â”œâ”€â”¤â”‚  â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”¤
   â•© â”´ â”´â”´â”˜â””â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜  â•© â•©â”´ â”´â””â”€â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜
   """)

  print("--WELCOME NEW ASTRONEER!---")
  print()
  optXa = 0
  optXb = 0
  optXc = 0
  optXd = 0
  optXf = 0
  progressX = 0

  # user starts script
  time.sleep(1)
  print("Loading...")
  time.sleep(.5)
  print()
  print("AI Evaluator Connection Established")
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/intro2.wav', autoplay=True))


  print()


  nums = ["Â·","Âº","*","o"]
  tm = 0
  print("""\


                                       @@(@#@@                @@@                     /@
        @@                           @   @@@   @,            @ @ @                    @@
       @@                           @   @@ #@   @        @ .@ .@  @ *@         #      @@     @
      @@                            @  /@   @%  @         .@@@#@ @@@              @ @@@@@* @
      @@.                            @   @@@   @             .@@@               @@@@@@@@@@@ @@
      @@@      @ .,           @        @@ @,@@              @@   @*            .@@@@@@@@@@@@@&
       @@@@  @   @           @           *@#              .@      ,@              .@@@@@@@@
        .@@@@   @         @@@             @,              @         @                 @@   @
           &@@@@@@@@@@@@@@.             @@@@@               @(   @@            @      @@
                 %@@@(                    @                  .@@@                     @@
                                                               @                       @

                      """)
  time.sleep(.5)
  print("""\
   __             __        __  ___  ___  __
  /  ` |__|  /\  |__)  /\  /  `  |  |__  |__)
  \__, |  | /~~\ |  \ /~~\ \__,  |  |___ |  \
   __        __   __   ___  __  ___    __
  /__` |  | / _` / _` |__  /__`  |  | /  \ |\ |
  .__/ \__/ \__> \__> |___ .__/  |  | \__/ | \|
         __   __             ___
   |\/| /  \ |  \ |  | |    |__
   |  | \__/ |__/ \__/ |___ |___
                                                """)
  time.sleep(1)
  while tm < 2:
      print(random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),random.randrange(1,5)* " ",
      random.choice(nums),)

      tm = tm + 0.1

      time.sleep(0.1)

  print()
  print("- INSTRUCTIONS -")
  time.sleep(.5)
  print("Respond to prompts with 1, 2, 3, or 4 and then press ENTER.")
  time.sleep(.5)
  print()
  print("Loading...")
  time.sleep(.5)
  print("- MODULE REGISTERED -")
  time.sleep(.5)
  print( "STARTING CHARACTER ANALYSIS")
  time.sleep(.5)
  time.sleep(.5)
  print()
  print("Reading data...")
  time.sleep(.5)
  time.sleep(4.5)

  # define the ask function globals
  def ask (q, QAudio, qs, qt, a, b, c, d):
    global optXa
    global optXb
    global optXc
    global optXd
    global optXf
    global progressX
    print()
    print()

  # the question format
    display(Audio(filename=QAudio))
    print(q)
    time.sleep(.5)
    print(qt)
    time.sleep(float(qs))
    print("1 - " + a)
    time.sleep(1)
    print("2 - " + b)
    time.sleep(1)
    print("3 - " + c)
    time.sleep(1)
    print("4 - " + d)
    print()

  # did they give us a number? this is mostly to block accidental input, or return key mashing...

    while True:
      try:
        ans = int(input("Enter an integer number: "))
        break
      except ValueError:
        # they did not, in fact, give us a number...
          print("Please input integer only...")
          continue

    print("Response recorded:", ans)
    print()

  # Get user's answer's and assign variables
    if ans == int("1"):
      optXa += 1
      progressX += 1
    elif ans == int("2"):
      optXb += 1
      progressX += 1
    elif ans == int("3"):
      optXc += 1
      progressX += 1
    elif ans == int("4"):
      optXd += 1
      progressX += 1
    else:
      # user is a smartass
      print("Invalid response recorded!")
      optXf += 1
      progressX += 1
    print()

  # the actual questions
  while optXf < 1 and progressX < 7:
      try:
        ask(q="001", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q1.wav', qt="You need someone to do something for you. Which is your most likely approach?", qs="5.5", a="Make it seem like it was their idea.", c="Convince them everyone else has already agreed.", d="Blackmail.", b="Butter them up.")
        ask(q="002", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q2.wav', qt="4", qt="A stranger has left their wallet behind at the commissary. What do you do?", a="Check their ID. Maybe take some cash. Return it to their department head.", b="Check their ID. Return it to their department head. Do not take any cash.", c="Drop it off at security. Maybe take some cash.", d="Take some cash. Maybe take the wallet to security.")
        ask(q="003", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q3.wav', qt="1.5", qt="How do you handle verbal disagreements?", a="I live to debate.", b="I like to take all sides into account before committing.", c="I try to bring people around to my point of view. ", d="I disagree and I leave.")
        ask(q="004OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||SKIPPING|||||||", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q4.wav', qt="20", qt="YouandRandyhav||||||||||||||||||||SKIPPING|||||||005|||||||||||Choose a word.||||HOLDING||||||||", a="Analytical", b="Comfort", c="Collaborate ", d="Spontaneous")
        ask(q="006", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q6.wav', qt="1.5", qt="Choose a word.", a="Mesmerize", b="Nurture", c="Motivate", d="Enviable")
        ask(q="007", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q7.wav', qt=".5", qt="Choose a word.", a="Agreeable", b="Soup", c="Staunch", d="Mechanical")
        ask(q="008", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q8.wav', qt="2", qt="Congratulations. You made it to the final question. Pick an element.", a="Gold.", b="Oxygen.", c="Uranium.", d="Helium.")
      except Exception as e:
        print(e)

  ######## END REPEAT ####
  ######## OUTPUT ########

  print("RESULTS")
  time.sleep(.5)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")

  # drumroll please...

  # the user was naughty
  if optXf > 0:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/STARS.wav', autoplay=True))
    time.sleep(12.5)
    os.system('color 06')
    print("""\

                                   @@@@
                                  @@@@@@
                                 @@ @@ @@
                            @@@%@#  @@  &@&@@@
                              @@@@@ @@ @@@@@
                                  @@@@@@
                                  @@@@@@
                                @@&    @@@
                               @@        @@
                             %@            @%
                               @#        &@
                                 @@    @@
                                  @@@@@#
                                    @@


      `.. ..      `..   `..     `..    `....         `....     `..
    `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
     `..      `..       `..     `..`..        `..`..        `..`..
       `..    `..       `...... `..`..        `..`..        `..`..
          `.. `..       `..     `..`..        `..`..        `..`..
    `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
      `.. ..     `....  `..     `..    `....         `....     `........
                       __  _____    _______    , __
                      / ')  /  '      /  ' )  / /  `
                     /  /,-/-,     --/    /--/ /--
                    (__/(_/       (_/    /  (_(___,

           `.. ..  `... `......      `.       `.......      `.. ..
         `..    `..     `..         `. ..     `..    `..  `..    `..
          `..           `..        `.  `..    `..    `..   `..
            `..         `..       `..   `..   `. `..         `..
               `..      `..      `...... `..  `..  `..          `..
         `..    `..     `..     `..       `.. `..    `..  `..    `..
           `.. ..       `..    `..         `..`..      `..  `.. ..

    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
    time.sleep(1)
    time.sleep(4)
    print("Evaluator has terminated the connection.")

  # normal results
  elif optXa > optXb and optXa > optXc and optXa > optXd:
    time.sleep(2)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 06')
    print("""\

                                   @@@@
                                  @@@@@@
                                 @@ @@ @@
                            @@@%@#  @@  &@&@@@
                              @@@@@ @@ @@@@@
                                  @@@@@@
                                  @@@@@@
                                @@&    @@@
                               @@        @@
                             %@            @%
                               @#        &@
                                 @@    @@
                                  @@@@@#
                                    @@


      `.. ..      `..   `..     `..    `....         `....     `..
    `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
     `..      `..       `..     `..`..        `..`..        `..`..
       `..    `..       `...... `..`..        `..`..        `..`..
          `.. `..       `..     `..`..        `..`..        `..`..
    `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
      `.. ..     `....  `..     `..    `....         `....     `........
                       __  _____    _______    , __
                      / ')  /  '      /  ' )  / /  `
                     /  /,-/-,     --/    /--/ /--
                    (__/(_/       (_/    /  (_(___,

           `.. ..  `... `......      `.       `.......      `.. ..
         `..    `..     `..         `. ..     `..    `..  `..    `..
          `..           `..        `.  `..    `..    `..   `..
            `..         `..       `..   `..   `. `..         `..
               `..      `..      `...... `..  `..  `..          `..
         `..    `..     `..     `..       `.. `..    `..  `..    `..
           `.. ..       `..    `..         `..`..      `..  `.. ..

    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
    time.sleep(5)
  elif optXb > optXa and optXb > optXc and optXb > optXd:
    time.sleep(2)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 09')
    print("""\

        ,@@
       @@@
      &@@
      @@@
      @@@
      @@@@        @@ @
      .@@@@(    &    @              @@
        @@@@@%      @             @@@
          @@@@@   &           &@@@@
             @@@@@@@@@@@@@@@@@@@
                  @@@@@@@@@@

     ____  ____   __   _, ____,____, __
    (-(__`(-/  ` (-|__|  (-/  (-/  \(-|
     ____)  \___, _|  |_,  \__/ \__/ _|__,
    (____, ____, (  ____, __   _, __(_,
    (-/  \(-|_,    (-|   (-|__|  (-|_,
      \__/ _|       _|    _|  |_, _|__,
          (        (     (       (
     _____,   ____,____, ____,
    (-| | |  (-/  (-/  \(-|  |
     _| | |_,  \__/ \__/ _|  |_,
    (                   (


    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE MOON")
    time.sleep(5)
  elif optXc > optXa and optXc > optXa and optXc > optXd:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 04')
    print("""\

                                @@@
                                @@@
                                @@@
                        /@      @@@       @
                           @  @@@@@@@  *@
                     @@     @@@@@@@@@@@,     @#
                           @@@@@@@@@@@@@@
                @@@@@@@@@ .@@@@@@@@@@@@@@ ,@@@@@@@@
                            @@@@@@@@@@@@
                           /   @@@@@   @
                         @      @@@      @
                                @@@
                                @@@
                                @#@

    ___  ___ _  _  ___   ___  _       ___  ___   __  __   _   _  _
   / __|/ __| || |/ _ \ / _ \| |     / _ \| __| |  \/  | /_\ | \| |
   \__ \ (__| __ | (_) | (_) | |__  | (_) | _|  | |\/| |/ _ \| .` |
   |___/\___|_||_|\___/ \___/|____|  \___/|_|   |_|  |_/_/ \_\_|\_|
    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF MAN")
    time.sleep(5)
  elif optXd > optXa and optXd > optXb and optXd > optXc:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 05')
    print("""\

                                         @@# @@@  @@@
                                       @@    @@@&    @@
                                      @     @@@@@@    *@
                                     #@    @@    @@    @
                                      @    @@    @@    @
                                      &@    .@@@@     @,
                                         @&  @@@   @@
                                            *@@@@.
                                             (@@
                                              @@
                                              @@
                                            @@@@@%
                                              @@
                                              @

     o-o    o-o o  o  o-o   o-o  o         o-o  o--o     o    o-O-o  o-o  o  o o-O-o
    |      /    |  | o   o o   o |        o   o |        |      |   o     |  |   |
     o-o  O     O--O |   | |   | |        |   | O-o      |      |   |  -o O--O   |
        |  \    |  | o   o o   o |        o   o |        |      |   o   | |  |   |
    o--o    o-o o  o  o-o   o-o  O---o     o-o  o        O---oo-O-o  o-o  o  o   o

        """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF LIGHT")
    time.sleep(5)

  # tiebreaker time
  else:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/STARS.wav', autoplay=True))
    time.sleep(12.5)
    os.system('color 06')
    print("""\

                                   @@@@
                                  @@@@@@
                                 @@ @@ @@
                            @@@%@#  @@  &@&@@@
                              @@@@@ @@ @@@@@
                                  @@@@@@
                                  @@@@@@
                                @@&    @@@
                               @@        @@
                             %@            @%
                               @#        &@
                                 @@    @@
                                  @@@@@#
                                    @@


      `.. ..      `..   `..     `..    `....         `....     `..
    `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
     `..      `..       `..     `..`..        `..`..        `..`..
       `..    `..       `...... `..`..        `..`..        `..`..
          `.. `..       `..     `..`..        `..`..        `..`..
    `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
      `.. ..     `....  `..     `..    `....         `....     `........
                       __  _____    _______    , __
                      / ')  /  '      /  ' )  / /  `
                     /  /,-/-,     --/    /--/ /--
                    (__/(_/       (_/    /  (_(___,

           `.. ..  `... `......      `.       `.......      `.. ..
         `..    `..     `..         `. ..     `..    `..  `..    `..
          `..           `..        `.  `..    `..    `..   `..
            `..         `..       `..   `..   `. `..         `..
               `..      `..      `...... `..  `..  `..          `..
         `..    `..     `..     `..       `.. `..    `..  `..    `..
           `.. ..       `..    `..         `..`..      `..  `.. ..

    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
    time.sleep(1)
    time.sleep(4)
    print("Evaluator has terminated the connection.")
  print("-------")
elif opta > optb and opta > optc and opta > optd:
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")
  time.sleep(2)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
  os.system('color 06')
  print("""\

                                 @@@@
                                @@@@@@
                               @@ @@ @@
                          @@@%@#  @@  &@&@@@
                            @@@@@ @@ @@@@@
                                @@@@@@
                                @@@@@@
                              @@&    @@@
                             @@        @@
                           %@            @%
                             @#        &@
                               @@    @@
                                @@@@@#
                                  @@


    `.. ..      `..   `..     `..    `....         `....     `..
  `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
   `..      `..       `..     `..`..        `..`..        `..`..
     `..    `..       `...... `..`..        `..`..        `..`..
        `.. `..       `..     `..`..        `..`..        `..`..
  `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
    `.. ..     `....  `..     `..    `....         `....     `........
                     __  _____    _______    , __
                    / ')  /  '      /  ' )  / /  `
                   /  /,-/-,     --/    /--/ /--
                  (__/(_/       (_/    /  (_(___,

         `.. ..  `... `......      `.       `.......      `.. ..
       `..    `..     `..         `. ..     `..    `..  `..    `..
        `..           `..        `.  `..    `..    `..   `..
          `..         `..       `..   `..   `. `..         `..
             `..      `..      `...... `..  `..  `..          `..
       `..    `..     `..     `..       `.. `..    `..  `..    `..
         `.. ..       `..    `..         `..`..      `..  `.. ..

  """)
  print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
  time.sleep(5)
elif optb > opta and optb > optc and optb > optd:
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")
  time.sleep(2)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
  os.system('color 09')
  print("""\

      ,@@
     @@@
    &@@
    @@@
    @@@
    @@@@        @@ @
    .@@@@(    &    @              @@
      @@@@@%      @             @@@
        @@@@@   &           &@@@@
           @@@@@@@@@@@@@@@@@@@
                @@@@@@@@@@

   ____  ____   __   _, ____,____, __
  (-(__`(-/  ` (-|__|  (-/  (-/  \(-|
   ____)  \___, _|  |_,  \__/ \__/ _|__,
  (____, ____, (  ____, __   _, __(_,
  (-/  \(-|_,    (-|   (-|__|  (-|_,
    \__/ _|       _|    _|  |_, _|__,
        (        (     (       (
   _____,   ____,____, ____,
  (-| | |  (-/  (-/  \(-|  |
   _| | |_,  \__/ \__/ _|  |_,
  (                   (


  """)
  print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE MOON")
  time.sleep(5)
elif optc > opta and optc > opta and optc > optd:
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")
  time.sleep(2)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
  os.system('color 04')
  print("""\

                              @@@
                              @@@
                              @@@
                      /@      @@@       @
                         @  @@@@@@@  *@
                   @@     @@@@@@@@@@@,     @#
                         @@@@@@@@@@@@@@
              @@@@@@@@@ .@@@@@@@@@@@@@@ ,@@@@@@@@
                          @@@@@@@@@@@@
                         /   @@@@@   @
                       @      @@@      @
                              @@@
                              @@@
                              @#@

  ___  ___ _  _  ___   ___  _       ___  ___   __  __   _   _  _
 / __|/ __| || |/ _ \ / _ \| |     / _ \| __| |  \/  | /_\ | \| |
 \__ \ (__| __ | (_) | (_) | |__  | (_) | _|  | |\/| |/ _ \| .` |
 |___/\___|_||_|\___/ \___/|____|  \___/|_|   |_|  |_/_/ \_\_|\_|
  """)
  print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF MAN")
  time.sleep(5)
elif optd > opta and optd > optb and optd > optc:
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")
  time.sleep(2)
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
  os.system('color 05')
  print("""\

                                       @@# @@@  @@@
                                     @@    @@@&    @@
                                    @     @@@@@@    *@
                                   #@    @@    @@    @
                                    @    @@    @@    @
                                    &@    .@@@@     @,
                                       @&  @@@   @@
                                          *@@@@.
                                           (@@
                                            @@
                                            @@
                                          @@@@@%
                                            @@
                                            @

   o-o    o-o o  o  o-o   o-o  o         o-o  o--o     o    o-O-o  o-o  o  o o-O-o
  |      /    |  | o   o o   o |        o   o |        |      |   o     |  |   |
   o-o  O     O--O |   | |   | |        |   | O-o      |      |   |  -o O--O   |
      |  \    |  | o   o o   o |        o   o |        |      |   o   | |  |   |
  o--o    o-o o  o  o-o   o-o  O---o     o-o  o        O---oo-O-o  o-o  o  o   o

      """)
  print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF LIGHT")
  time.sleep(5)
else:
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
  time.sleep(6)
  print("-------")
  time.sleep(2)
  print("Additional analysis required. Please wait...")
  display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/tiebreaker.wav', autoplay=True))
  time.sleep(8)
  print("Loading....")
  os.system('color 0b')

  input("Press enter to continue.")

  print()
  optQa = 0
  optQb = 0
  optQc = 0
  optQd = 0
  optQf = 0
  progressQ = 0

  def ask (q, QAudio, qs, qt, a, b, c, d):
    global optQa
    global optQb
    global optQc
    global optQd
    global optQf
    global progressQ
    import time
    print()
    print()

    display(Audio(filename=QAudio))
    print(q)
    time.sleep(10)
    print(qt)
    time.sleep(float(qs))
    print("1 - " + a)
    time.sleep(1)
    print("2 - " + b)
    time.sleep(1)
    print("3 - " + c)
    time.sleep(1)
    print("4 - " + d)
    print()

    while True:
      try:
        ans = int(input("Enter an integer number: "))
        break
      except ValueError:
          print("Please input integer only...")
          continue

    print("Response recorded:", ans)
    print()

    if ans == int("1"):
      optQa += 1
      progressQ += 1
    elif ans == int("2"):
      optQb += 1
      progressQ += 1
    elif ans == int("3"):
      optQc += 1
      progressQ += 1
    elif ans == int("4"):
      optQd += 1
      progressQ += 1
    else:
      # user is a smartass
      print("Invalid response recorded!")
      optQf += 1
      progressQ += 1
    print()


  while optQf < 1 and progressQ < 1:
      try:
        ask(q="009", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/bonus.wav', qt="3", qt="What do you do when someone is taking up too much of your time?", a="Situationally forgiving, but try to tactfully take my leave.", b="It doesn't bother me.", c="I tell them I need to leave and then I leave.", d="I make a mental note to waste their time later in exchange.")
      except Exception as e:
        print(e)

  print("RESULTS")
  time.sleep(.5)
  print("-------")

  if optQf > 0:
    time.sleep(.5)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/idiot.wav', autoplay=True))
    time.sleep(4)
    print("""\
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@                @@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@                         @@@@@@@@@@@@@@@
    @@@@@@@@@@@@                               @@@@@@@@@@@@
    @@@@@@@@@@                                   @@@@@@@@@@
    @@@@@@@@@         @@@              @@@         @@@@@@@@
    @@@@@@@,       @@@@@@@@         @@@@@@@@        @@@@@@@
    @@@@@@@           @@@              @@@           @@@@@@
    @@@@@@                  @@@@@@@/                 @@@@@@
    @@@@@@                 @@@@@@@@@/                 @@@@@
    @@@@@@         @@%     /@@@@@@@@      @@@        &@@@@@
    @@@@@@.        @@@        (@@        @@@         @@@@@@
    @@@@@@@         /@@@               &@@@         @@@@@@@
    @@@@@@@@          /@@@@#        @@@@@          @@@@@@@@
    @@@@@@@@@@            @@@@@@@@@@@*            @@@@@@@@@
    @@@@@@@@@@@/                                @@@@@@@@@@@
    @@@@@@@@@@@@@@                           %@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@                   ,@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
    ___     _             _        __   ___
    / __| __| |_  ___  ___| |  ___ / _| |   \ _  _ _ _  __ ___ ___
    \__ \/ _| ' \/ _ \/ _ \ | / _ \  _| | |) | || | ' \/ _/ -_|_-<
    |___/\__|_||_\___/\___/_| \___/_|   |___/ \_,_|_||_\__\___/__/
    """)
    print("You are School of Dunces")
    time.sleep(16.5)
    print("Alert! Evaluator has terminated the session!")
    print("-------")
    print("Evaluator feedback: You know what you did.")
    time.sleep(3)
    print("Resetting....")
    input("Press enter to reconnect.")
    #here we go again...
    os.system('color 0b')
    print("""\
    â•¦â”Œâ”â”Œâ”¬â”â”Œâ”€â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”Œâ”€â”â”¬  â”¬  â”Œâ”€â”â”¬â”€â”
    â•‘â”‚â”‚â”‚â”‚ â”œâ”¤ â”œâ”¬â”˜â””â”€â” â”‚ â”œâ”¤ â”‚  â”‚  â”œâ”€â”¤â”œâ”¬â”˜
    â•©â”˜â””â”˜â”´ â””â”€â”˜â”´â””â”€â””â”€â”˜ â”´ â””â”€â”˜â”´â”€â”˜â”´â”€â”˜â”´ â”´â”´â””â”€
    â•”â•â•—â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”â”Œâ”€â”  â•”â•â•—â”Œâ”€â”â”Œâ”â”Œâ”Œâ”€â”â”Œâ”¬â”â”¬â”€â”â”Œâ”€â”â”Œâ”¬â”â”¬â”Œâ”€â”â”Œâ”â”Œ
    â•šâ•â•—â”œâ”€â”˜â”œâ”€â”¤â”‚  â”œâ”¤   â• â•â•â”œâ”¤ â”‚â”‚â”‚â”œâ”¤  â”‚ â”œâ”¬â”˜â”œâ”€â”¤ â”‚ â”‚â”‚ â”‚â”‚â”‚â”‚
    â•šâ•â•â”´  â”´ â”´â””â”€â”˜â””â”€â”˜  â•©  â””â”€â”˜â”˜â””â”˜â””â”€â”˜ â”´ â”´â””â”€â”´ â”´ â”´ â”´â””â”€â”˜â”˜â””â”˜
    â•”â•¦â•—â”¬ â”¬â”¬â”Œâ”â”Œâ”¬â”Œâ”€â”¬â”Œâ”â”Œâ”Œâ”€â”  â•”â•¦â•—â”Œâ”€â”â”Œâ”€â”â”¬ â”¬â”¬â”Œâ”â”Œâ”Œâ”€â”
     â•‘ â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”´â”â”‚â”‚â”‚â”‚â”‚ â”¬  â•‘â•‘â•‘â”œâ”€â”¤â”‚  â”œâ”€â”¤â”‚â”‚â”‚â”‚â”œâ”¤
     â•© â”´ â”´â”´â”˜â””â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜  â•© â•©â”´ â”´â””â”€â”˜â”´ â”´â”´â”˜â””â”˜â””â”€â”˜
     """)

    print("--WELCOME NEW ASTRONEER!---")
    print()
    optZa = 0
    optZb = 0
    optZc = 0
    optZd = 0
    optZf = 0
    progressZ = 0

    # user starts script
    time.sleep(1)
    print("Loading...")
    time.sleep(.5)
    print()
    print("AI Evaluator Connection Established")
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/intro2.wav', autoplay=True))


    print()


    nums = ["Â·","Âº","*","o"]
    tm = 0
    print("""\


                                         @@(@#@@                @@@                     /@
          @@                           @   @@@   @,            @ @ @                    @@
         @@                           @   @@ #@   @        @ .@ .@  @ *@         #      @@     @
        @@                            @  /@   @%  @         .@@@#@ @@@              @ @@@@@* @
        @@.                            @   @@@   @             .@@@               @@@@@@@@@@@ @@
        @@@      @ .,           @        @@ @,@@              @@   @*            .@@@@@@@@@@@@@&
         @@@@  @   @           @           *@#              .@      ,@              .@@@@@@@@
          .@@@@   @         @@@             @,              @         @                 @@   @
             &@@@@@@@@@@@@@@.             @@@@@               @(   @@            @      @@
                   %@@@(                    @                  .@@@                     @@
                                                                 @                       @

                        """)
    time.sleep(.5)
    print("""\
     __             __        __  ___  ___  __
    /  ` |__|  /\  |__)  /\  /  `  |  |__  |__)
    \__, |  | /~~\ |  \ /~~\ \__,  |  |___ |  \
     __        __   __   ___  __  ___    __
    /__` |  | / _` / _` |__  /__`  |  | /  \ |\ |
    .__/ \__/ \__> \__> |___ .__/  |  | \__/ | \|
           __   __             ___
     |\/| /  \ |  \ |  | |    |__
     |  | \__/ |__/ \__/ |___ |___
                                                  """)
    time.sleep(1)
    while tm < 2:
        print(random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),random.randrange(1,5)* " ",
        random.choice(nums),)

        tm = tm + 0.1

        time.sleep(0.1)

    print()
    print("- INSTRUCTIONS -")
    time.sleep(.5)
    print("Respond to prompts with 1, 2, 3, or 4 and then press ENTER.")
    time.sleep(.5)
    print()
    print("Loading...")
    time.sleep(.5)
    print("- MODULE REGISTERED -")
    time.sleep(.5)
    print( "STARTING CHARACTER ANALYSIS")
    time.sleep(.5)
    time.sleep(.5)
    print()
    print("Reading data...")
    time.sleep(.5)
    time.sleep(4.5)

    # define the ask function globals
    def ask (q, QAudio, qs, qt, a, b, c, d):
      global optZa
      global optZb
      global optZc
      global optZd
      global optZf
      global progressZ
      print()
      print()

    # the question format
      display(Audio(filename=QAudio))
      print(q)
      time.sleep(.5)
      print(qt)
      time.sleep(float(qs))
      print("1 - " + a)
      time.sleep(1)
      print("2 - " + b)
      time.sleep(1)
      print("3 - " + c)
      time.sleep(1)
      print("4 - " + d)
      print()

    # did they give us a number? this is mostly to block accidental input, or return key mashing...

      while True:
        try:
          ans = int(input("Enter an integer number: "))
          break
        except ValueError:
          # they did not, in fact, give us a number...
            print("Please input integer only...")
            continue

      print("Response recorded:", ans)
      print()

    # Get user's answer's and assign variables
      if ans == int("1"):
        optZa += 1
        progressZ += 1
      elif ans == int("2"):
        optZb += 1
        progressZ += 1
      elif ans == int("3"):
        optZc += 1
        progressZ += 1
      elif ans == int("4"):
        optZd += 1
        progressZ += 1
      else:
        # user is a smartass
        print("Invalid response recorded!")
        optZf += 1
        progressZ += 1
      print()

    # the actual questions
    while optZf < 1 and progressZ < 7:
        try:
          ask(q="001", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q1.wav', qt="You need someone to do something for you. Which is your most likely approach?", qs="5.5", a="Make it seem like it was their idea.", c="Convince them everyone else has already agreed.", d="Blackmail.", b="Butter them up.")
          ask(q="002", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q2.wav', qt="4", qt="A stranger has left their wallet behind at the commissary. What do you do?", a="Check their ID. Maybe take some cash. Return it to their department head.", b="Check their ID. Return it to their department head. Do not take any cash.", c="Drop it off at security. Maybe take some cash.", d="Take some cash. Maybe take the wallet to security.")
          ask(q="003", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q3.wav', qt="1.5", qt="How do you handle verbal disagreements?", a="I live to debate.", b="I like to take all sides into account before committing.", c="I try to bring people around to my point of view. ", d="I disagree and I leave.")
          ask(q="004OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||||||||||||||||||||||OVERRIDE||||||||SKIPPING|||||||", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q4.wav', qt="20", qt="YouandRandyhav||||||||||||||||||||SKIPPING|||||||005|||||||||||Choose a word.||||HOLDING||||||||", a="Analytical", b="Comfort", c="Collaborate ", d="Spontaneous")
          ask(q="006", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q6.wav', qt="1.5", qt="Choose a word.", a="Mesmerize", b="Nurture", c="Motivate", d="Enviable")
          ask(q="007", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/Q7.wav', qt=".5", qt="Choose a word.", a="Agreeable", b="Soup", c="Staunch", d="Mechanical")
          ask(q="008", QAudio='/content/drive/MyDrive/Colab Notebooks/Audio/2Q8.wav', qt="2", qt="Congratulations. You made it to the final question. Pick an element.", a="Gold.", b="Oxygen.", c="Uranium.", d="Helium.")
        except Exception as e:
          print(e)

    ######## END REPEAT ####
    ######## OUTPUT ########

    print("RESULTS")
    time.sleep(.5)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/done.wav', autoplay=True))
    time.sleep(6)
    print("-------")

    # drumroll please...

    # the user was naughty
    if optZf > 0:
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/STARS.wav', autoplay=True))
      time.sleep(12.5)
      os.system('color 06')
      print("""\

                                     @@@@
                                    @@@@@@
                                   @@ @@ @@
                              @@@%@#  @@  &@&@@@
                                @@@@@ @@ @@@@@
                                    @@@@@@
                                    @@@@@@
                                  @@&    @@@
                                 @@        @@
                               %@            @%
                                 @#        &@
                                   @@    @@
                                    @@@@@#
                                      @@


        `.. ..      `..   `..     `..    `....         `....     `..
      `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
       `..      `..       `..     `..`..        `..`..        `..`..
         `..    `..       `...... `..`..        `..`..        `..`..
            `.. `..       `..     `..`..        `..`..        `..`..
      `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
        `.. ..     `....  `..     `..    `....         `....     `........
                         __  _____    _______    , __
                        / ')  /  '      /  ' )  / /  `
                       /  /,-/-,     --/    /--/ /--
                      (__/(_/       (_/    /  (_(___,

             `.. ..  `... `......      `.       `.......      `.. ..
           `..    `..     `..         `. ..     `..    `..  `..    `..
            `..           `..        `.  `..    `..    `..   `..
              `..         `..       `..   `..   `. `..         `..
                 `..      `..      `...... `..  `..  `..          `..
           `..    `..     `..     `..       `.. `..    `..  `..    `..
             `.. ..       `..    `..         `..`..      `..  `.. ..

      """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
      time.sleep(1)
      time.sleep(4)
      print("Evaluator has terminated the connection.")

    # normal results
    elif optZa > optZb and optZa > optZc and optZa > optZd:
      time.sleep(2)
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
      os.system('color 06')
      print("""\

                                     @@@@
                                    @@@@@@
                                   @@ @@ @@
                              @@@%@#  @@  &@&@@@
                                @@@@@ @@ @@@@@
                                    @@@@@@
                                    @@@@@@
                                  @@&    @@@
                                 @@        @@
                               %@            @%
                                 @#        &@
                                   @@    @@
                                    @@@@@#
                                      @@


        `.. ..      `..   `..     `..    `....         `....     `..
      `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
       `..      `..       `..     `..`..        `..`..        `..`..
         `..    `..       `...... `..`..        `..`..        `..`..
            `.. `..       `..     `..`..        `..`..        `..`..
      `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
        `.. ..     `....  `..     `..    `....         `....     `........
                         __  _____    _______    , __
                        / ')  /  '      /  ' )  / /  `
                       /  /,-/-,     --/    /--/ /--
                      (__/(_/       (_/    /  (_(___,

             `.. ..  `... `......      `.       `.......      `.. ..
           `..    `..     `..         `. ..     `..    `..  `..    `..
            `..           `..        `.  `..    `..    `..   `..
              `..         `..       `..   `..   `. `..         `..
                 `..      `..      `...... `..  `..  `..          `..
           `..    `..     `..     `..       `.. `..    `..  `..    `..
             `.. ..       `..    `..         `..`..      `..  `.. ..

      """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
      time.sleep(5)
    elif optZb > optZa and optZb > optZc and optZb > optZd:
      time.sleep(2)
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
      os.system('color 09')
      print("""\

          ,@@
         @@@
        &@@
        @@@
        @@@
        @@@@        @@ @
        .@@@@(    &    @              @@
          @@@@@%      @             @@@
            @@@@@   &           &@@@@
               @@@@@@@@@@@@@@@@@@@
                    @@@@@@@@@@

       ____  ____   __   _, ____,____, __
      (-(__`(-/  ` (-|__|  (-/  (-/  \(-|
       ____)  \___, _|  |_,  \__/ \__/ _|__,
      (____, ____, (  ____, __   _, __(_,
      (-/  \(-|_,    (-|   (-|__|  (-|_,
        \__/ _|       _|    _|  |_, _|__,
            (        (     (       (
       _____,   ____,____, ____,
      (-| | |  (-/  (-/  \(-|  |
       _| | |_,  \__/ \__/ _|  |_,
      (                   (


      """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE MOON")
      time.sleep(5)
    elif optZc > optZa and optZc > optZa and optZc > optZd:
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
      os.system('color 04')
      print("""\

                                  @@@
                                  @@@
                                  @@@
                          /@      @@@       @
                             @  @@@@@@@  *@
                       @@     @@@@@@@@@@@,     @#
                             @@@@@@@@@@@@@@
                  @@@@@@@@@ .@@@@@@@@@@@@@@ ,@@@@@@@@
                              @@@@@@@@@@@@
                             /   @@@@@   @
                           @      @@@      @
                                  @@@
                                  @@@
                                  @#@

      ___  ___ _  _  ___   ___  _       ___  ___   __  __   _   _  _
     / __|/ __| || |/ _ \ / _ \| |     / _ \| __| |  \/  | /_\ | \| |
     \__ \ (__| __ | (_) | (_) | |__  | (_) | _|  | |\/| |/ _ \| .` |
     |___/\___|_||_|\___/ \___/|____|  \___/|_|   |_|  |_/_/ \_\_|\_|
      """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF MAN")
      time.sleep(5)
    elif optZd > optZa and optZd > optZb and optZd > optZc:
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
      os.system('color 05')
      print("""\

                                           @@# @@@  @@@
                                         @@    @@@&    @@
                                        @     @@@@@@    *@
                                       #@    @@    @@    @
                                        @    @@    @@    @
                                        &@    .@@@@     @,
                                           @&  @@@   @@
                                              *@@@@.
                                               (@@
                                                @@
                                                @@
                                              @@@@@%
                                                @@
                                                @

       o-o    o-o o  o  o-o   o-o  o         o-o  o--o     o    o-O-o  o-o  o  o o-O-o
      |      /    |  | o   o o   o |        o   o |        |      |   o     |  |   |
       o-o  O     O--O |   | |   | |        |   | O-o      |      |   |  -o O--O   |
          |  \    |  | o   o o   o |        o   o |        |      |   o   | |  |   |
      o--o    o-o o  o  o-o   o-o  O---o     o-o  o        O---oo-O-o  o-o  o  o   o

          """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF LIGHT")
      time.sleep(5)

    # tiebreaker time
    else:
      display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/STARS.wav', autoplay=True))
      time.sleep(12.5)
      os.system('color 06')
      print("""\

                                     @@@@
                                    @@@@@@
                                   @@ @@ @@
                              @@@%@#  @@  &@&@@@
                                @@@@@ @@ @@@@@
                                    @@@@@@
                                    @@@@@@
                                  @@&    @@@
                                 @@        @@
                               %@            @%
                                 @#        &@
                                   @@    @@
                                    @@@@@#
                                      @@


        `.. ..      `..   `..     `..    `....         `....     `..
      `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
       `..      `..       `..     `..`..        `..`..        `..`..
         `..    `..       `...... `..`..        `..`..        `..`..
            `.. `..       `..     `..`..        `..`..        `..`..
      `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
        `.. ..     `....  `..     `..    `....         `....     `........
                         __  _____    _______    , __
                        / ')  /  '      /  ' )  / /  `
                       /  /,-/-,     --/    /--/ /--
                      (__/(_/       (_/    /  (_(___,

             `.. ..  `... `......      `.       `.......      `.. ..
           `..    `..     `..         `. ..     `..    `..  `..    `..
            `..           `..        `.  `..    `..    `..   `..
              `..         `..       `..   `..   `. `..         `..
                 `..      `..      `...... `..  `..  `..          `..
           `..    `..     `..     `..       `.. `..    `..  `..    `..
             `.. ..       `..    `..         `..`..      `..  `.. ..

      """)
      print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
      time.sleep(1)
      time.sleep(4)
      print("Evaluator has terminated the connection.")


  elif optQa > optQb and optQa > optQc and optQa > optQd:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/out.wav', autoplay=True))
    time.sleep(6)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 06')
    print("""\

                                   @@@@
                                  @@@@@@
                                 @@ @@ @@
                            @@@%@#  @@  &@&@@@
                              @@@@@ @@ @@@@@
                                  @@@@@@
                                  @@@@@@
                                @@&    @@@
                               @@        @@
                             %@            @%
                               @#        &@
                                 @@    @@
                                  @@@@@#
                                    @@


      `.. ..      `..   `..     `..    `....         `....     `..
    `..    `.. `..   `..`..     `..  `..    `..    `..    `..  `..
     `..      `..       `..     `..`..        `..`..        `..`..
       `..    `..       `...... `..`..        `..`..        `..`..
          `.. `..       `..     `..`..        `..`..        `..`..
    `..    `.. `..   `..`..     `..  `..     `..   `..     `.. `..
      `.. ..     `....  `..     `..    `....         `....     `........
                       __  _____    _______    , __
                      / ')  /  '      /  ' )  / /  `
                     /  /,-/-,     --/    /--/ /--
                    (__/(_/       (_/    /  (_(___,

           `.. ..  `... `......      `.       `.......      `.. ..
         `..    `..     `..         `. ..     `..    `..  `..    `..
          `..           `..        `.  `..    `..    `..   `..
            `..         `..       `..   `..   `. `..         `..
               `..      `..      `...... `..  `..  `..          `..
         `..    `..     `..     `..       `.. `..    `..  `..    `..
           `.. ..       `..    `..         `..`..      `..  `.. ..

    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE STARS")
    time.sleep(5)
  elif optQb > optQa and optQb > optQc and optQb > optQd:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/out.wav', autoplay=True))
    time.sleep(6)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 09')
    print("""\

        ,@@
       @@@
      &@@
      @@@
      @@@
      @@@@        @@ @
      .@@@@(    &    @              @@
        @@@@@%      @             @@@
          @@@@@   &           &@@@@
             @@@@@@@@@@@@@@@@@@@
                  @@@@@@@@@@

     ____  ____   __   _, ____,____, __
    (-(__`(-/  ` (-|__|  (-/  (-/  \(-|
     ____)  \___, _|  |_,  \__/ \__/ _|__,
    (____, ____, (  ____, __   _, __(_,
    (-/  \(-|_,    (-|   (-|__|  (-|_,
      \__/ _|       _|    _|  |_, _|__,
          (        (     (       (
     _____,   ____,____, ____,
    (-| | |  (-/  (-/  \(-|  |
     _| | |_,  \__/ \__/ _|  |_,
    (                   (


    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF THE MOON")
    time.sleep(5)
  elif optQc > optQa and optQc > optQa and optQc > optQd:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/out.wav', autoplay=True))
    time.sleep(6)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 04')
    print("""\

                                @@@
                                @@@
                                @@@
                        /@      @@@       @
                           @  @@@@@@@  *@
                     @@     @@@@@@@@@@@,     @#
                           @@@@@@@@@@@@@@
                @@@@@@@@@ .@@@@@@@@@@@@@@ ,@@@@@@@@
                            @@@@@@@@@@@@
                           /   @@@@@   @
                         @      @@@      @
                                @@@
                                @@@
                                @#@

    ___  ___ _  _  ___   ___  _       ___  ___   __  __   _   _  _
   / __|/ __| || |/ _ \ / _ \| |     / _ \| __| |  \/  | /_\ | \| |
   \__ \ (__| __ | (_) | (_) | |__  | (_) | _|  | |\/| |/ _ \| .` |
   |___/\___|_||_|\___/ \___/|____|  \___/|_|   |_|  |_/_/ \_\_|\_|
    """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF MAN")
    time.sleep(5)
  elif optQd > optQa and optQd > optQb and optQd > optQc:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/out.wav', autoplay=True))
    time.sleep(6)
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/resultping.wav', autoplay=True))
    os.system('color 05')
    print("""\

                                         @@# @@@  @@@
                                       @@    @@@&    @@
                                      @     @@@@@@    *@
                                     #@    @@    @@    @
                                      @    @@    @@    @
                                      &@    .@@@@     @,
                                         @&  @@@   @@
                                            *@@@@.
                                             (@@
                                              @@
                                              @@
                                            @@@@@%
                                              @@
                                              @

     o-o    o-o o  o  o-o   o-o  o         o-o  o--o     o    o-O-o  o-o  o  o o-O-o
    |      /    |  | o   o o   o |        o   o |        |      |   o     |  |   |
     o-o  O     O--O |   | |   | |        |   | O-o      |      |   |  -o O--O   |
        |  \    |  | o   o o   o |        o   o |        |      |   o   | |  |   |
    o--o    o-o o  o  o-o   o-o  O---o     o-o  o        O---oo-O-o  o-o  o  o   o

        """)
    print("ANALYSIS COMPLETE. SUGGESTED RESULT: SCHOOL OF LIGHT")
    time.sleep(5)

  else:
    display(Audio(filename='/content/drive/MyDrive/Colab Notebooks/Audio/broke.wav', autoplay=True))
    print("How is this even possible?")
  print("-------")

print("CONNECTION CLOSED! HAVE A GREAT DAY SPACE EXPLORER!")
time.sleep(100)
